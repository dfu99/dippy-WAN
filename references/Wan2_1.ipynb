# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir /root/.ssh/

# Copy '/content/drive/Colab Notebooks/utils/id_ed25519' to /root/.ssh
# !cp '/content/drive/MyDrive/Colab Notebooks/utils/id_ed25519' /root/.ssh/.
# !chmod 700 /root/.ssh
# !chmod 600 /root/.ssh/id_ed25519
# !ssh-keyscan -t ed25519 github.com >> /root/.ssh/known_hosts
# !chmod 644 /root/.ssh/known_hosts
# !ssh -T git@github.com || true
# Out:
# # github.com:22 SSH-2.0-ae0a932
# Hi dfu99! You've successfully authenticated, but GitHub does not provide shell access.

# %%
# !git clone git@github.com:dfu99/Wan2.1-shared.git
# Out:
# Cloning into 'Wan2.1-shared'...
# remote: Enumerating objects: 157, done.
# remote: Counting objects: 100% (157/157), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 157 (delta 86), reused 156 (delta 85), pack-reused 0 (from 0)
# Receiving objects: 100% (157/157), 83.99 KiB | 469.00 KiB/s, done.
# Resolving deltas: 100% (86/86), done.

# %%
# !pip install transformers diffusers accelerate gradio spaces ftfy peft imageio-ffmpeg opencv-python safetensors sentencepiece
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.2/105.2 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 5.5 MB/s eta 0:00:00
# ...

# %%
import os
from google.colab import userdata

# Load the token from secrets and set it as an environment variable
try:
    os.environ['HF_TOKEN'] = userdata.get('HF_TOKEN')
except Exception as e:
    print(f"Could not load HF_TOKEN: {e}")
    print("Please ensure you have added a secret named 'HF_TOKEN' in the secrets tab (key icon on the left).")

# !python /content/Wan2.1-shared/app-colab.py
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Loading weights: 100% 519/519 [00:00<00:00, 732.92it/s, Materializing param=vision_model.pre_layrnorm.weight]
# CLIPVisionModel LOAD REPORT from: Wan-AI/Wan2.1-I2V-14B-480P-Diffusers
# Key                      | Status     |  |
# -------------------------+------------+--+-
# visual_projection.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:202: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `hf_hub_download`. Downloading to a local directory does not use symlinks anymore.
# ...
